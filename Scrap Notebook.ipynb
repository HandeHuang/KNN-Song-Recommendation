# %%
#import time
#import os
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import tkinter as tk
from tkinter import filedialog
#%config InlineBackend.figure_format ='retina'
#import random
#from functools import reduce
#import spotipy
#import spotipy.util as util
#from spotipy.oauth2 import SpotifyClientCredentials
#from spotipy import oauth2

# %%
# !pwd
# Out:
# /Users/jspr/CMSE_202/repositories/Wrapped_Project

# %%
stream1 = pd.read_json('Jake Streaming History1.json')
stream2 = pd.read_json('Jake Streaming History2.json')
stream3 = pd.read_json('Jake Streaming History3.json')

# %%
artists = {}

for i in stream1['artistName']:
    if i not in artists:
        artists[i] = 1
    if i in artists:
        artists[i] += 1

for j in stream2['artistName']:
    if j not in artists:
        artists[j] = 1
    if j in artists:
        artists[j] += 1
        
for k in stream3['artistName']:
    if k not in artists:
        artists[k] = 1
    if k in artists:
        artists[k] += 1

art_lists = sorted(artists.items(),key = lambda kv: kv[1],reverse = True)
art_lists
# Out:
# [('Gorillaz', 1112),
#  ('Daft Punk', 839),
#  ('The Beatles', 650),
#  ('insaneintherainmusic', 411),
#  ('Kanye West', 393),
#  ('The Killers', 360),
#  ('Greta Van Fleet', 307),
#  ('アトラスサウンドチーム', 301),
#  ('C418', 290),
#  ('The Front Bottoms', 275),
#  ('Bring Me The Horizon', 270),
#  ('Glass Animals', 262),
#  ('Muse', 258),
#  ('Panic! At The Disco', 253),
#  ('Fall Out Boy', 239),
#  ('Pink Floyd', 233),
#  ('NOTHING MORE', 218),
#  ('John Williams', 215),
#  ('Christopher Larkin', 202),
#  ('Weezer', 192),
#  ('Led Zeppelin', 187),
#  ('Childish Gambino', 186),
#  ('Ninja Sex Party', 184),
#  ('Linkin Park', 164),
#  ('Silversun Pickups', 161),
#  ('Vulfpeck', 146),
#  ('While She Sleeps', 140),
#  ('SEATBELTS', 137),
#  ('Foo Fighters', 137),
#  ('The Strokes', 128),
#  ('Mumford & Sons', 128),
#  ('Incubus', 128),
#  ('Red Hot Chili Peppers', 124),
#  ('Metallica', 115),
#  ('Young the Giant', 110),
#  ('Lil Nas X', 108),
#  ('Lyn', 107),
#  ('I The Mighty', 106),
# ...

# %%
x = []
y = []

for i in art_lists:
    #for bar graph
    x.append(i[0])
    y.append(i[1])

# %%
stream1
# Out:
#                endTime         artistName                    trackName  \
# 0     2021-04-03 07:52        The Beatles  Let It Be - Remastered 2009
# 1     2021-04-03 07:52        The Beatles  Let It Be - Remastered 2009
# 2     2021-04-03 07:59        The Beatles  Let It Be - Remastered 2015
# 3     2021-04-03 08:07  League of Legends          Space Groove - 2021
# 4     2021-04-03 18:57       NOTHING MORE                   Sex & Lies
# ...                ...                ...                          ...
# 9995  2021-09-22 19:54        The Killers          For Reasons Unknown
# 9996  2021-09-22 19:58        The Killers                 Read My Mind
# 9997  2021-09-22 20:02        The Killers                  Uncle Jonny
# 9998  2021-09-22 20:06        The Killers                        Bones
# 9999  2021-09-22 20:10        The Killers                      My List
#
#       msPlayed
# 0        29376
# 1         1536
# 2        20032
# 3        22058
# 4         1962
# ...        ...
# ...

# %%
client_id = '14498f1851cb44baa6af1641d5d1b650'
client_secret = 'f68c94b6e4d445e9a005062e95e0be8d'

# %%
import spotipy as sp
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

spotify = sp.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id,client_secret))
results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:5]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/fc80a280376d5142c888475bd8fdcd00b4fc8d7d?cid=14498f1851cb44baa6af1641d5d1b650
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/e5910b86cc788766388cca1c494094e39186aa1e?cid=14498f1851cb44baa6af1641d5d1b650
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/f3765a6c5b194302c6e7fffc31ba21e2bd616cf6?cid=14498f1851cb44baa6af1641d5d1b650
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Black Dog - Remaster
# audio    : https://p.scdn.co/mp3-preview/f82af31817a7ec198a709e68f0f0f9edfc9a7e81?cid=14498f1851cb44baa6af1641d5d1b650
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Kashmir - Remaster
# ...

# %%
def get_artist(name):
    results = spotify.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

# %%
lz = get_artist('led zeppelin')
lz
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#  'followers': {'href': None, 'total': 12070864},
#  'genres': ['album rock', 'classic rock', 'hard rock', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#  'id': '36QJpDe2go2KgaRleHCDTp',
#  'images': [{'height': 600,
#    'url': 'https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e',
#    'width': 600},
#   {'height': 200,
#    'url': 'https://i.scdn.co/image/b0248a44865493e6a03832aa89854ada16ff07a8',
#    'width': 200},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/16eb3cdae0d824b520ac17710e943a99d3ef6602',
#    'width': 64}],
#  'name': 'Led Zeppelin',
#  'popularity': 81,
#  'type': 'artist',
#  'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}

# %%
top = []
roco = 0
for i in art_lists:
    if roco < 6:
        top.append(i[0])
    roco += 1

top
# Out:
# ['Gorillaz',
#  '岩垂徳行',
#  'Daft Punk',
#  'Capcom Sound Team',
#  'Kanye West',
#  'The Beatles']

# %%
reco = []
for i in top:
    reco.append(get_artist(i))
#spotify.recommendation_genre_seeds()
save = reco[4]['genres']
save
#spotify.
# Out:
# ['chicago rap', 'rap']

# %%
root = tk.Tk()
root.withdraw()

files = filedialog.askopenfilenames()

# %%
blank = {}
blank['dog'] = ['kiss',1]

# %%
print(blank['dog'])
blank['dog'][1] = int(blank['dog'][1])+1
print(blank['dog'])
# Out:
# ['kiss', 1]
# ['kiss', 2]
