# %% [markdown]
# # Things left to do:
#
#     1. (Jacob) 10 top genres
#     2.  (Han)     msPlayed*each feature, then get avg
#     3.  ()     Last step: use top genres and top artists to select from knn output, take repetitive ones out
#
#     4.  ()     merge multiple user data files function

# %%
#import time
#import os
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import tkinter as tk
from tkinter import filedialog
# %config InlineBackend.figure_format ='retina'
import random
from functools import reduce
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy import oauth2

# %%
#####CHANGE TO IMPORT YOUR FILE(s) ONLY######
hannah = pd.read_json('Hannah Streaming History.json')

# %%
def merge_files():
    pass

# %%
def get_100_favorite_artists(stream):
    artists = {}

    for j in stream['artistName']:
        if j not in artists:
            artists[j] = 1
        elif j in artists:
            artists[j] += 1
    art_lists = sorted(artists.items(),key = lambda kv: kv[1],reverse = True)
    
    artist_list = []
    for i in art_lists[:100]:
        artist_list.append(i[0])
        
    return artist_list

# %%
####CHANGE TO YOUR DATA####
hannah_art = get_100_favorite_artists(hannah)
hannah_art
# Out:
# ['岩垂徳行',
#  'Capcom Sound Team',
#  'Billie Eilish',
#  "Hi I'm Case",
#  'dodie',
#  'The Score',
#  'Distractible',
#  'Cavetown',
#  'Panic! At The Disco',
#  'Yasumasa Kitagawa',
#  'MISSIO',
#  'Masakazu Sugimori',
#  'I DONT KNOW HOW BUT THEY FOUND ME',
#  'X Ambassadors',
#  'AJR',
#  'grandson',
#  'half•alive',
#  '尾野寺真未',
#  'Cosmo Sheldrake',
#  'Imagine Dragons',
#  'Alec Benjamin',
#  'Gabbie Hanna',
#  'Post Malone',
#  'Set It Off',
#  '山田靖子',
#  'DJ Khalil',
#  'Lil Wayne',
#  'Yoshiya Terayama',
#  'Thutmose',
#  'Call Me Karizma',
#  'Ski Mask The Slump God',
#  'Satoshi Hori',
#  'Nicki Minaj',
#  'Duckwrth',
#  'Beau Young Prince',
#  'Jaden',
#  'Elliphant',
#  'Vince Staples',
#  'The Unlikely Candidates',
#  'Aminé',
#  'WILLOW',
#  'Fall Out Boy',
#  'Louie Zong',
#  'Jon Cozart',
#  'Liana Flores',
#  'Get Scared',
#  'Adventure Time',
#  'Mother Mother',
#  'Andy Black',
#  'Anarbor',
#  'Juice WRLD',
#  'Steven Universe',
#  'Ed Sheeran',
#  'Anthony Amorim',
#  'Hozier',
#  'Shortly',
#  'Blackway',
#  'Hiromitsu Maeba',
#  'Dan Avidan',
#  'Johnny Cash',
#  'AWOLNATION',
#  'Sleeping At Last',
#  'Mitski',
#  'Twenty One Pilots',
#  'Thomas Sanders',
#  'Ninja Sex Party',
#  'Garrett Watts',
#  'Hanna Ward',
#  'Mumford & Sons',
#  'IRONTOM',
#  'Hugh Jackman',
#  'Unlike Pluto',
#  'Saint Motel',
#  'Linkin Park',
#  'Yung Gravy',
#  'Shameik Moore',
#  'Tally Hall',
#  'Savlonic',
#  'Caravan Palace',
#  'Mystery Skulls',
#  'SIAMES',
#  'Still Woozy',
#  'Barns Courtney',
#  'Catie Turner',
#  'Ethan Bortnick',
#  'Glass Animals',
#  'The Cab',
#  'The Oh Hellos',
#  'Brooke Alexx',
#  'Dominurmom',
#  'Penelope Scott',
#  'Chris Garneau',
#  'UPSAHL',
#  'The Offspring',
#  'Kenshi Yonezu',
#  'AKEMI KIMURA',
#  'Palehound',
#  'Regina Spektor',
#  'American Authors',
#  'Halsey']

# %%
#########SEE 2 CELLS ABOVE##########
hannah
# Out:
#                endTime         artistName         trackName  msPlayed
# 0     2021-04-06 00:40  Capcom Sound Team          大逆転裁判・評決    179158
# 1     2021-04-10 05:17  Capcom Sound Team          大逆転裁判・評決     14089
# 2     2021-04-10 05:17               岩垂徳行        『襲われたオドロキ』     19466
# 3     2021-04-10 05:20  Capcom Sound Team       留置所 〜薄闇の狂詩曲    175800
# 4     2021-04-10 05:24               岩垂徳行  カンガエルート 〜シナプスの共鳴    108880
# ...                ...                ...               ...       ...
# 3436  2022-04-08 04:24               岩垂徳行       捜査 〜中盤 2011    178960
# 3437  2022-04-08 04:26  Capcom Sound Team  星影宇宙ノ介 〜老い、悔い、報い     98360
# 3438  2022-04-08 04:28               岩垂徳行           きみょうな人々    163813
# 3439  2022-04-08 04:30  Masakazu Sugimori        追憶 〜DL6号事件    123893
# 3440  2022-04-08 04:31              尾野寺真未          逆転裁判6・序章     21486
#
# [3441 rows x 4 columns]

# %%
###########CHANGE hannah TO WHAT YOU DEFINED EARLIER##########
hannah.sort_values('msPlayed', ascending = False).head(100)
# Out:
#                endTime    artistName                   trackName  msPlayed
# 1921  2021-10-05 00:18  Distractible                      Future   3840301
# 3175  2022-03-23 01:28  Distractible   Disappointing Our Parents   3668206
# 2612  2022-02-19 05:36  Distractible  The Distractible Threesome   3557734
# 2580  2022-02-17 02:13  Distractible              Waste of Money   3475867
# 1976  2021-10-13 04:58  Distractible         Dreams & Nightmares   3428925
# ...                ...           ...                         ...       ...
# 1001  2021-07-26 11:09  Hugh Jackman                 From Now On    349560
# 710   2021-07-07 07:45  Hugh Jackman                 From Now On    349560
# 1558  2021-08-07 10:21  Hugh Jackman                 From Now On    349560
# 1250  2021-07-29 06:56  Hugh Jackman                 From Now On    349560
# 1413  2021-07-30 06:42  Hugh Jackman                 From Now On    349560
#
# [100 rows x 4 columns]

# %%
def get_track_name_time_artist(filename):
    tracks = {}
    stream = pd.read_json(filename)

    for i in range(len(stream)):
        name = stream['trackName'][i]
        time = stream['msPlayed'][i]
        artist = stream['artistName'][i]
        if name not in tracks:
            tracks[name] = [time,artist]
        elif name in tracks:
            tracks[name][0] += time
    tracks = sorted(tracks.items(),key = lambda kv: kv[1],reverse = True)
    df = pd.DataFrame(tracks, columns =['track_names','time_artist'])

        
    return tracks,df

# %%
######### CHANGE THE STRING PART TO YOUR OWN DATA ############
tracks,tracks_time = get_track_name_time_artist('Hannah Streaming History.json')

# %%
tracks_time
# Out:
#                                            track_names  \
# 0                                              Old Men
# 1    Elevate (feat. Denzel Curry, YBN Cordae, SwaVa...
# 2                             Sick of Losing Soulmates
# 3                                              Monster
# 4                                           To The End
# ..                                                 ...
# 869                                       Heart Shaped
# 870                             Thus Always To Tyrants
# 871                             So She Goes - Acoustic
# 872                                         The Engine
# 873                     Wake Me up When September Ends
#
#                  time_artist
# 0    [6610292, Distractible]
# 1       [5716199, DJ Khalil]
# 2           [5595783, dodie]
# 3           [5353676, dodie]
# 4       [5195460, Elliphant]
# ..                       ...
# 869        [853, Boosegumps]
# 870     [341, The Oh Hellos]
# 871            [106, Geskle]
# 872           [42, Plas Teg]
# 873           [0, Green Day]
#
# [874 rows x 2 columns]

# %%
all_songs = pd.read_csv('tracks.csv')
all_songs = all_songs.drop(columns = ['duration_ms','explicit','id','id_artists','mode'])
all_songs = all_songs.drop_duplicates(subset = ['name', 'artists'],
                                     keep = 'last').reset_index(drop = True)

# %%
final_all_songs = all_songs.sort_values('popularity', ascending = False)

# %%
final_all_songs
# Out:
#                                                      name  popularity  \
# 71644                                     drivers license          99
# 70806                                     Blinding Lights          96
# 69971                                             Streets          94
# 71645                                                Fiel          94
# 71646   Friday (feat. Mufasa & Hypeman) - Dopamine Re-...          94
# ...                                                   ...         ...
# 59089             Amazing Grace - 2003 Remastered Version           0
# 59087                   Beware of the Dog - 2003 Remaster           0
# 59084               Pisser Dans Un Violon - 2003 Remaster           0
# 59082                       Boneless (the Town Fair 2003)           0
# 412784               If I Had Any Sense, I'd Go Back Home           0
#
#                                                   artists release_date  \
# 71644                                  ['Olivia Rodrigo']   2021-01-08
# 70806                                      ['The Weeknd']   2020-03-20
# 69971                                        ['Doja Cat']   2019-11-07
# 71645         ['Los Legendarios', 'Wisin', 'Jhay Cortez']   2021-02-04
# 71646   ['Riton', 'Nightcrawlers', 'Mufasa & Hypeman',...   2021-01-15
# ...                                                   ...          ...
# 59089                                  ['The Groundhogs']         2010
# 59087                                     ['Kevin Ayers']   2012-04-23
# 59084                                     ['Kevin Ayers']   2012-04-23
# 59082   ['Blaise Kolodychuk and the Fukachuk Egg Machi...   2018-12-08
# 412784                                   ['Louis Jordan']         1953
#
#         danceability  energy  key  loudness  speechiness  acousticness  \
# 71644          0.585  0.4360   10    -8.761       0.0601       0.72100
# 70806          0.514  0.7300    1    -5.934       0.0598       0.00146
# 69971          0.749  0.4630   11    -8.433       0.0828       0.20800
# 71645          0.849  0.7010    6    -4.407       0.0600       0.40700
# 71646          0.824  0.8620    2    -3.424       0.1260       0.00760
# ...              ...     ...  ...       ...          ...           ...
# 59089          0.198  0.1020    1   -16.169       0.0337       0.57200
# 59087          0.309  0.0669    6   -17.630       0.0379       0.98800
# 59084          0.334  0.2110   11   -24.595       0.1470       0.78900
# 59082          0.568  0.6900    7   -10.528       0.0320       0.20500
# 412784         0.638  0.4770    3    -6.839       0.0315       0.69500
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 71644           0.000013    0.1050   0.1320  143.874               4
# 70806           0.000095    0.0897   0.3340  171.005               4
# 69971           0.037100    0.3370   0.1900   90.028               4
# 71645           0.000000    0.1120   0.5050   98.005               4
# 71646           0.000132    0.3030   0.8010  122.980               4
# ...                  ...       ...      ...      ...             ...
# 59089           0.826000    0.1130   0.0502   77.957               3
# 59087           0.785000    0.0649   0.0718   92.636               1
# 59084           0.565000    0.3310   0.0398  167.773               3
# 59082           0.964000    0.1610   0.4160   79.998               4
# 412784          0.000121    0.3020   0.6580   94.544               3
#
# [526610 rows x 15 columns]

# %%
names = tracks_time['track_names'].values.tolist()

# %%
#takes about 5 min to search for 900 songs

###############CHANGE hannah_all TO YourName_all###############

hannah_all = pd.DataFrame()
for i in range(len(names)):
    name = names[i]
    artist = tracks_time['time_artist'][i][1]
    formatted = '[\''+artist+'\']'
    
    mask1 = final_all_songs['name'] == name
    mask2 = final_all_songs['artists'] == formatted
    hannah_all = hannah_all.append(final_all_songs[mask1&mask2])

# %%
############CHANGE TO WHAT YOU DEFINED IN THE PREV. CELL#################
hannah_all
# Out:
#                                   name  popularity              artists  \
# 389244        Sick of Losing Soulmates          64            ['dodie']
# 223516                         Machine          66  ['Imagine Dragons']
# 500361                     The Phoenix          39     ['Fall Out Boy']
# 92329                        bellyache          69    ['Billie Eilish']
# 67150                       Devil Town          78         ['Cavetown']
# ...                                ...         ...                  ...
# 503181                        Flamingo          55    ['Kenshi Yonezu']
# 68482                      Pretty Girl          79           ['Clairo']
# 500769                   MAD HEAD LOVE          43    ['Kenshi Yonezu']
# 82746                      Basket Case          80        ['Green Day']
# 151103  Wake Me up When September Ends          56        ['Green Day']
#
#        release_date  danceability  energy  key  loudness  speechiness  \
# 389244   2016-10-14         0.478   0.241    2   -17.122       0.0386
# 223516   2018-11-09         0.638   0.679    4    -5.278       0.0425
# 500361   2013-01-01         0.562   0.964    4    -2.991       0.0720
# 92329    2017-12-22         0.695   0.573    4    -8.597       0.1060
# 67150    2015-11-09         0.576   0.759    3    -8.165       0.0599
# ...             ...           ...     ...  ...       ...          ...
# 503181   2020-08-05         0.760   0.668    7    -6.000       0.0546
# 68482    2017-08-04         0.930   0.611    0    -4.406       0.0415
# 500769   2014-04-23         0.611   0.963   11    -2.500       0.0643
# 82746    1994-02-01         0.442   0.943    3    -3.205       0.0602
# 151103   2004-09-21         0.546   0.814    7    -5.146       0.0314
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 389244      0.716000          0.216000    0.3540    0.110   75.285
# 223516      0.001600          0.006550    0.1210    0.596   81.045
# 500361      0.000539          0.000002    0.5790    0.410  138.063
# 92329       0.460000          0.073400    0.4820    0.408   99.939
# 67150       0.120000          0.000000    0.1210    0.501   99.969
# ...              ...               ...       ...      ...      ...
# 503181      0.165000          0.000000    0.0917    0.913  114.075
# 68482       0.593000          0.001240    0.0592    0.695  112.127
# 500769      0.009800          0.000000    0.1210    0.825  106.061
# 82746       0.002930          0.000009    0.0910    0.781   85.064
# 151103      0.023000          0.000000    0.0972    0.146  104.980
#
#         time_signature
# 389244               4
# 223516               4
# 500361               4
# 92329                4
# 67150                4
# ...                ...
# 503181               4
# 68482                4
# 500769               4
# 82746                4
# 151103               4
#
# [158 rows x 15 columns]

# %%
####### DO LATER: EACH FEATURE TIMES BY TIME LISTENED, THEN AVERAGE ##########
print(hannah_all.describe().loc['mean'])
print(hannah_all.describe().loc['mean'].values.tolist())
Center = hannah_all.describe().loc['mean'].values.tolist()
del Center[0] #pop
del Center[2] #key
#del Center[8] #tempo, if uncomment, have to change below to 8 too.
del Center[9] #time_sig
print(Center)
# Out:
# popularity           65.462025
# danceability          0.589614
# energy                0.615519
# key                   5.234177
# loudness             -7.503576
# speechiness           0.077581
# acousticness          0.286060
# instrumentalness      0.072253
# liveness              0.174116
# valence               0.470481
# tempo               116.758582
# time_signature        3.955696
# Name: mean, dtype: float64
# [65.4620253164557, 0.5896139240506327, 0.6155189873417719, 5.234177215189874, -7.503575949367088, 0.07758101265822784, 0.2860602278481013, 0.07225287835443038, 0.17411582278481014, 0.470481012658228, 116.75858227848094, 3.9556962025316458]
# [0.5896139240506327, 0.6155189873417719, -7.503575949367088, 0.07758101265822784, 0.2860602278481013, 0.07225287835443038, 0.17411582278481014, 0.470481012658228, 116.75858227848094]

# %%
# use: 
#     dance
#     energy
#     loudness
#     speech
#     acoust
#     instru
#     live
#     valen

# optional:
#     popularity
#     tempo

# do not use:
#     key
#     time_sig

# %%
def set_up_nineD(df):
    N = len(df)
    nineD = np.zeros([N,9])
    for i in range(N):
        nineD[i,0] = df['danceability'][i]
        nineD[i,1] = df['energy'][i]
        nineD[i,2] = df['loudness'][i]
        nineD[i,3] = df['speechiness'][i]
        nineD[i,4] = df['acousticness'][i]
        nineD[i,5] = df['instrumentalness'][i]
        nineD[i,6] = df['liveness'][i]
        nineD[i,7] = df['valence'][i]
        nineD[i,8] = df['tempo'][i]
    return nineD

# %%
from math import *
# Function for computing the distance between two points
def distance(p1,p2):
    '''Returns the distance betwen two points'''
    return sqrt((p1[0] - p2[0])**2 + 
                (p1[1] - p2[1])**2 +
                (p1[2] - p2[2])**2 +
                (p1[3] - p2[3])**2 +
                (p1[4] - p2[4])**2 +
                (p1[5] - p2[5])**2 +
                (p1[6] - p2[6])**2 +
                (p1[7] - p2[7])**2 +
                (p1[8] - p2[8])**2)

# %%
#k nearest neighbors
def knn (Center,nineD,k=3):
    N = len(nineD)
    dist_list = []
    for i in range(N):
        dist = distance(Center,nineD[i])
        dist_list.append(dist)
    
    min_value = []
    min_index = []
    for j in range(k):
        min_val = sorted(dist_list)[j]
        min_value.append(min_val)
        
        min_ind = dist_list.index(min_val)
        min_index.append(min_ind)
    return min_value , min_index

# %%
# #selecting top () popular songs from all
small_all = final_all_songs.head(100000)
small_all = small_all.reset_index()

# %%
nineD = set_up_nineD(small_all)

# %%
#ok for fun
ok = 10
min_value , min_index = knn(Center,nineD,k=ok)

# %%
min_index
# Out:
# [67572, 23214, 9761, 93220, 99303, 14113, 3154, 41016, 20428, 55870]

# %%
recommendation_df = small_all.loc[[45178, 5867, 93353, 22273, 54954, 1610, 25935, 24598, 55047, 95993]]
recommendation_df = recommendation_df.reset_index()
recommendation_df
# Out:
#    level_0   index                                 name  popularity  \
# 0    45178  484403  I Come Apart (feat. Florence Welch)          53
# 1     5867  250454                              Nervous          68
# 2    93353  170541            Pasajera En Trance - Live          44
# 3    22273   62136                               Do You          59
# 4    54954  337727                                 Line          51
# 5     1610  258974                   The Bigger Picture          75
# 6    25935  163898                         Show Me Love          58
# 7    24598  346479                         D'improvviso          58
# 8    55047  347524                             Io e Lei          51
# 9    95993  468606                   Cheppave Chirugali          44
#
#                             artists release_date  danceability  energy  key  \
# 0  ['A$AP Rocky', 'Florence Welch']         2013         0.589   0.616    1
# 1             ['The Neighbourhood']   2018-11-02         0.589   0.614    0
# 2                 ['Charly García']   1995-08-06         0.591   0.614    0
# 3                         ['Ne-Yo']   2007-01-01         0.588   0.614    5
# 4                    ['Izzamuzzic']   2017-09-28         0.592   0.616    9
# 5                      ['Lil Baby']   2020-06-12         0.590   0.618    1
# 6    ['Sam Feldt', 'Kimberly Anne']   2015-05-18         0.589   0.613    0
# 7               ['Lorenzo Fragola']   2016-03-11         0.587   0.616    8
# 8              ['Vago', 'Cifra149']   2019-05-30         0.592   0.614   11
# 9       ['Udit Narayan', 'Sujatha']   2003-01-17         0.588   0.618   11
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -3.401       0.0986        0.5170          0.000009    0.1230    0.305
# 1    -7.528       0.0426        0.0213          0.165000    0.3100    0.318
# 2   -10.492       0.0410        0.5270          0.017500    0.9790    0.601
# 3    -5.857       0.0726        0.3100          0.000000    0.3210    0.590
# 4   -11.010       0.0649        0.2760          0.880000    0.1180    0.110
# 5    -5.756       0.3340        0.0127          0.000000    0.2440    0.153
# 6    -5.034       0.0327        0.5680          0.000000    0.0675    0.190
# 7    -6.578       0.0388        0.6530          0.000000    0.0976    0.326
# 8    -9.098       0.1920        0.4680          0.000000    0.1880    0.285
# 9    -9.554       0.1180        0.0509          0.000000    0.0956    0.503
#
#      tempo  time_signature
# 0   83.938               4
# 1  119.837               4
# 2   99.280               4
# 3  121.299               5
# 4  128.024               4
# 5   96.459               3
# 6  114.853               4
# 7  129.769               4
# 8   73.023               4
# 9  157.446               3

# %%
#see the "ok" above
for i in range(ok):
    print(recommendation_df['name'][i], recommendation_df['artists'][i],'\n')
# Out:
# I Come Apart (feat. Florence Welch) ['A$AP Rocky', 'Florence Welch']
#
# Nervous ['The Neighbourhood']
#
# Pasajera En Trance - Live ['Charly García']
#
# Do You ['Ne-Yo']
#
# Line ['Izzamuzzic']
#
# The Bigger Picture ['Lil Baby']
#
# Show Me Love ['Sam Feldt', 'Kimberly Anne']
#
# D'improvviso ['Lorenzo Fragola']
#
# Io e Lei ['Vago', 'Cifra149']
#
# Cheppave Chirugali ['Udit Narayan', 'Sujatha']

# %%
type(recommendation_df['artists'][0])
# Out:
# str

# %%
recommendation_df['artists'][0]
# Out:
# "['A$AP Rocky', 'Florence Welch']"

# %%
# client_id = '14498f1851cb44baa6af1641d5d1b650'
# client_secret = 'f68c94b6e4d445e9a005062e95e0be8d'

# %%
# import spotipy as sp
# from spotipy.oauth2 import SpotifyClientCredentials

# lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

# spotify = sp.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id,client_secret))
# results = spotify.artist_top_tracks(lz_uri)

# for track in results['tracks'][:5]:
#     print('track    : ' + track['name'])
#     print('audio    : ' + track['preview_url'])
#     print('cover art: ' + track['album']['images'][0]['url'])
#     print()

# %%
# def get_artist(name):
#     results = spotify.search(q='artist:' + name, type='artist')
#     items = results['artists']['items']
#     if len(items) > 0:
#         return items[0]
#     else:
#         return None

# %%
# lz = get_artist('led zeppelin')
# lz

# %%
# top = []
# roco = 0
# for i in art_lists:
#     if roco < 6:
#         top.append(i[0])
#     roco += 1

# top

# %%
# reco = []
# for i in top:
#     reco.append(get_artist(i))
# #spotify.recommendation_genre_seeds()
# save = reco[4]['genres']
# save
# #spotify.

# %%
# root = tk.Tk()
# root.withdraw()

# files = filedialog.askopenfilenames()
